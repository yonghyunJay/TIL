# %%
import requests
param = { 'name': 'Jason', 'age': 99 } # dict
res = requests.get('http://ggoreb.com/python/request.jsp', params = param)
print(res.status_code)
print(res.text)
# Out:
# 200
#
#
#
# method : GET<br>
# query string<br>
# key : age, value : 99<br>
# key : name, value : Jason<br>
# <br><br>
# header<br>
# key : accept, value : */*<br>
# key : Accept-Encoding, value : gzip, deflate<br>
# key : connection, value : close<br>
# key : host, value : ggoreb.com<br>
# key : HOSTING_CONTINENT_CODE, value : AS<br>
# key : HOSTING_COUNTRY_CODE, value : KR<br>
# key : HOSTING_WHITE_IP, value : false<br>
# key : user-agent, value : python-requests/2.22.0<br>
# key : X-Forwarded-Proto, value : http<br>
# key : X-SERVER_PORT, value : 80<br>
# key : X-SERVER_PROTOCOL, value : HTTP/1.1<br>
# key : X-SIMPLEXI, value : 222.107.238.25<br>
# key : content-length, value : 0<br>

# %%
import requests
header = { 'accept-language': 'en' }
res = requests.get('http://youtube.com', headers=header)
print(res.text)
# Out:
#   <!DOCTYPE html><html lang="en" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}</style><script name="www-roboto" >if (document.fonts && document.fonts.load) {docu
# ...

# %%
import requests

def get_html(url):
    html = ''
    res = requests.get(url)
    if res.status_code == 200:
        res.encoding = None #'utf-8'
    html = res.text
    return html

# %%
result = get_html('http://ggoreb.com/python/html/data1.html')
#print(result)
s_idx = 0
e_idx = 0
while True:
    s_idx = result.find('<td>', s_idx)
    if s_idx == -1: break
    e_idx = result.find('</td>', s_idx)
    print(result[s_idx+4 : e_idx])
    s_idx = e_idx
# Out:
# Jill
# Smith
# 50
# Eve
# Jackson
# 94
# John
# Doe
# 80

# %%
resNavFin = get_html('https://finance.naver.com')
resNavFin
# Out:
# '<html lang="ko">\n <head> \n  <title>네이버 금융</title> \n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" /> \n  <meta http-equiv="Content-Script-Type" content="text/javascript" /> \n  <meta http-equiv="Content-Style-Type" content="text/css" /> \n  <meta property="og:title" content="네이버 금융" /> \n  <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" /> \n  <meta property="og:url" content="https://finance.naver.com" /> \n  <meta property="og:description" content="국내 해외 증시 지수, 시장지표, 펀드, 뉴스, 증권사 리서치 등 제공" /> \n  <meta property="og:type" content="article" /> \n  <meta property="og:article:thumbnailUrl" content="" /> \n  <meta property="og:article:author" content="네이버금융" /> \n  <meta property="og:article:author:url" content="http://FINANCE.NAVER.COM" /> \n  <link rel="stylesheet" type="text/css" href="/css/finance_header.css?20200107172122" /> \n  <link rel="stylesheet" type="text/css" href="/css/finance.css?2020010717212
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(result, 'html.parser')

# %%
sel_tags = soup.select('.num_quot > .num')
for tag in sel_tags:
    print(tag.getText())
# Out:
# 2,231.55
# 681.97
# 300.12

# %%
ex10_1 = get_html('http://ggoreb.com/python/html/number.html')
soup = BeautifulSoup(ex10_1, 'html.parser')
sel_imgs = soup.select('.number > img')
for img in sel_imgs:
    print(img['alt'])
# Out:
# 1
# 4
# 10
# 12
# 28
# 45

# %%
ex10_2 = get_html('http://ggoreb.com/python/html/attribute.html')
soup = BeautifulSoup(ex10_2, 'html.parser')
sel_imgs = soup.select('.info > img')
for img in sel_imgs:
    print(img['src'], img['title'])
# Out:
# /images/luffy.jpg 루피
# /images/nami.jpg 나미
# /images/robin.jpg 로빈
# /images/zoro.jpg 조로

# %%
address = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn'
res = requests.get(address)
res.encoding = None

# %%
soup = BeautifulSoup(res.text, 'html.parser')
titles = soup.select('.tit3 > a')
for t in titles:
    #print(title.getText())
    print(t['title'])
# Out:
# 닥터 두리틀
# 백두산
# 스타워즈: 라이즈 오브 스카이워커
# 천문: 하늘에 묻는다
# 미드웨이
# 해치지않아
# 시동
# 나쁜 녀석들 : 포에버
# 남산의 부장들
# 겨울왕국 2
# 포드 V 페라리
# 나이브스 아웃
# 히트맨
# 지푸라기라도 잡고 싶은 짐승들
# 터미네이터: 다크 페이트
# 기생충
# 미스터 주: 사라진 VIP
# 카운트다운
# 극장판 원피스 스탬피드
# 비스티걸스
# 트레져 헌터: 비밀의 책
# 나이트 헌터
# 갱
# 21 브릿지: 테러 셧다운
# 피아니스트의 전설
# 청춘빌라 살인사건
# 신비아파트 극장판 하늘도깨비 대 요르문간드
# 울지마 톤즈 2 : 슈크란 바바
# 타오르는 여인의 초상
# 콰이어트 플레이스 2
# 라스트 선라이즈
# 여곡성
# 1917
# 콰이어트 플레이스
# 눈의 여왕4
# 프릭스
# 인셉션
# 스케치
# 마녀
# 6 언더그라운드
# 벌룬
# 타발루가와 얼음공주
# 로그 원: 스타워즈 스토리
# 엄마 바람피게하기
# 게이트키퍼 : 또 다른 세계
# 스파이즈
# 아이리시맨
# 스타워즈: 라스트 제다이
# 신의 은총으로
# 차일드 인 타임

# %%
address = 'https://search.wemakeprice.com/search?keyword=노트북'
res = requests.get(address)
res.encoding = None
soup = BeautifulSoup(res.text, 'html.parser')
options = soup.select('.option_txt')
for o in options:
    print(o.select_one('.text').text)
    print(o.select_one('.txt_price > .price_info').text)
# Out:
# [삼성전자] [최종혜택가 399,000원] 삼성 노트북5 NT55...
#
#
# 399,000원
#
#
# ㅣ
#
#                     628개 구매
#
#
# [삼성전자] [최종가 429,400원] 삼성 노트북5 NT550E...
#
#
# 429,400원
#
#
# ㅣ
#
#                     777개 구매
#
#
# [디지털위크] [디지털] ASUS 게이밍노트북 17형 ROG G7...
#
#
# 1,351,000원
#
#
# ㅣ
#
#                     366개 구매
#
#
# [디지털위크] [쿠폰+카드중복할인] HP 인기 가성비 & 게이밍 ...
#
#
# 369,600원外
#
#
# ㅣ
#
#                     928개 구매
#
#
# [디지털위크] [쿠폰+카드중복할인] HP 노트북 베스트 컬렉션!
#
#
# 428,910원外
#
#
# ㅣ
#
#                     189개 구매
#
#
# [디지털위크] LG 울트라PC 노트북 15UD590-GX30K 인...
#
#
# 593,400원
#
#
# ㅣ
#
#                     110개 구매
#
#
# [디지털위크] LG울트라PC 15U590-GA56K i5 대학생노...
#
#
# 895,410원
#
#
# ㅣ
#
#                     203개 구매
#
#
# [디지털위크] [쿠폰+카드중복할인] MSI PS / GF / GL...
#
#
# 1,129,000원外
#
#
# ㅣ
#
#                     124개 구매
#
#
# [디지털위크] [실구매가 693,120원] 삼성노트북7 NT730...
#
#
# 693,120원
#
#
# ㅣ
#
#                     63개 구매
#
#
# [디지털위크] [디지털]  ASUS TUF 게이밍노트북 FX505...
#
#
# 658,640원
#
#
# ㅣ
#
# ...

# %%
#address = 'https://www.coupang.com/np/search?q=노트북'
address = 'https://www.coupang.com/np/search?q=i7+%EB%85%B8%ED%8A%B8%EB%B6%81+%EB%A0%88%EB%85%B8%EB%B2%84&brand=&offerCondition=&filter=1%23attr_12292%2417480attr_12345%2418996attr_10234%243136%7C414401%23attr_11787%2417899attr_11146%2416981%40DEFAULT&availableDeliveryFilter=&filterType=&isPriceRange=false&priceRange=&minPrice=&maxPrice=&page=1&trcid=&traid=&filterSetByUser=true&channel=user&backgroundColor=&component=&rating=0&sorter=scoreDesc&listSize=36'
res = requests.get(address)
res.encoding = None
soup = BeautifulSoup(res.text, 'html.parser')
options = soup.select('.descriptions')
for o in options:
    print(o.select('.name'))
    print(o.select('.price-value'))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\dev\Miniconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# C:\dev\Miniconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://ggoreb.com/python/html/example.html')
soup = BeautifulSoup(res.text, 'html.parser')
#print(soup)
print(soup.find('div'))
print('='*20)
k = soup.find('div', {'class' : 'ex_class'})
print(k.find('p'))
# Out:
# <div>
# <p>a</p>
# <p>b</p>
# <p>c</p>
# </div>
# ...
# <p>d</p>

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://comic.naver.com/webtoon/list.nhn?titleId=732021')
soup = BeautifulSoup(res.text, 'html.parser')
titles = soup.select('td.title > a')
for title in titles:
    print(title.getText())
nums = soup.select('td.num')
for num in nums:
    print(num.getText())
# Out:
# 23화
# 22화
# 21화
# 20화
# 19화
# 18화
# 17화
# 16화
# 15화
# 14화
# 2020.01.10
# 2020.01.03
# 2019.12.27
# 2019.12.20
# 2019.12.13
# 2019.12.06
# 2019.11.29
# 2019.11.22
# 2019.11.15
# 2019.11.08

# %%
import requests
res = requests.get('http://ggoreb.com/python/json/data2.jsp')
result = res.json()
for r in result:
    print(r['name'], r['age'])
# Out:
# A 10
# B 11
# C 12

# %%
import requests
res = requests.get('http://ggoreb.com/python/json/data3.jsp')
result = res.json()
for obj in result:
    for o in obj['address']:
        print(o, end=' ')
    print()
# Out:
# 서울 신림
# 대전 탄방
# 부산 해운대

# %%
import requests
from bs4 import BeautifulSoup as bs

address = 'https://dapi.kakao.com/v2/local/search/address.xml'
params = {'query' : '서울특별시 동작구 신대방동 395'}
headers = {'Authorization' : 'KakaoAK d4be7b479f4b4cbd99bd19ae87f88b4b'}
res = requests.get(address, params=params, headers=headers)

# %%
soup = bs(res.text, 'html.parser')
address_list = soup.find_all('address')
for addr in address_list:
    x = addr.find('x')
    y = addr.find('y')
    name = addr.find('address_name')
    print(name.getText())
    print(x.text)
    print(y.text)
# Out:
# 서울 동작구 신대방동 395
# 126.92261248037842
# 37.49371334710509

# %%
import requests
from bs4 import BeautifulSoup as bs

address = 'https://kapi.kakao.com/v1/translation/translate'
params = {'query' : '안녕하세요', 'src_lang' : 'kr', 'target_lang' : 'vi'}
headers = {'Authorization' : 'KakaoAK d4be7b479f4b4cbd99bd19ae87f88b4b'}
res = requests.get(address, params=params, headers=headers)

# %%
print(res.json())
t = res.json()['translated_text']
print(t[0][0])
# Out:
# {'translated_text': [['Xin chào']]}
# Xin chào
